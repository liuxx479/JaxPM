# %%
# %pylab inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
field = np.load('field.npy')
initial_conditions = np.load('initial_conditions.npy')

figure(figsize=(12,6))
proj_axis = 0
subplot(121)
imshow(initial_conditions[:32].sum(axis=proj_axis), cmap='magma', extent=[0, 200, 0, 200])
xlabel('Mpc/h')
ylabel('Mpc/h')
title('Initial conditions')
subplot(122)
imshow(field[:32].sum(axis=proj_axis), cmap='magma', extent=[0,200,0,200])
xlabel('Mpc/h')
ylabel('Mpc/h')
title('1-LPT density field at z=0')
# Out:
# Text(0.5, 1.0, '1-LPT density field at z=0')
